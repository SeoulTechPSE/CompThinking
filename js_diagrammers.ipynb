# %% [markdown]
# # Notebook Javascript Diagrammers
#
# [![mermaid](https://mermaid-js.github.io/mermaid/img/flow.png)](https://github.com/innovationOUtside/nb_js_diagrammers)

# %%
# %%capture
# !pip install --upgrade nb-js-diagrammers

# %%
# %load_ext nb_js_diagrammers

# %% [markdown]
# ## [flowchart](https://flowchart.js.org/)

# %%
# %%flowchart_magic -h 100 -o flowchart.html
#
# st=>start: Start
# e=>end: End
# op1=>operation: Generate
# op2=>parallel: Evaluate
# st(right)->op1(right)->op2
# op2(path1, top)->op1
# op2(path2, right)->e
# Out:
#         <iframe
#             width="100%"
#             height="100"
#             src="flowchart.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## [wavedrom](https://wavedrom.com/)

# %%
# %%wavedrom_magic -h 100
#
# { signal : [
#   { name: "clk",  wave: "p......" },
#   { name: "bus",  wave: "x.34.5x",   data: "head body tail" },
#   { name: "wire", wave: "0.1..0." },
# ]}
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot;&gt;
#         &lt;title&gt;wavedrom.js&lt;/title&gt;
# &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/wavedrom/2.6.8/skins/default.js&quot; type=&quot;text/javascript&quot;&gt;&lt;/script&gt;
# &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/wavedrom/2.6.8/wavedrom.min.js&quot; type=&quot;text/javascript&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
#         &lt;body onload=&quot;WaveDrom.ProcessAll()&quot;&gt;
# &lt;script type=&quot;WaveDrom&quot;&gt;
#
# { signal : [
#   { name: &quot;clk&quot;,  wave: &quot;p......&quot; },
#   { name: &quot;bus&quot;,  wave: &quot;x.34.5x&quot;,   data: &quot;head body tail&quot; },
#   { name: &quot;wire&quot;, wave: &quot;0.1..0.&quot; },
# ]}
#
# &lt;/script&gt;
#         &lt;/body&gt;
# &lt;/html&gt;
# ...

# %% [markdown]
# ## [mermaid](https://mermaid-js.github.io/mermaid/#/)

# %%
# %%mermaid_magic -h 500
#
# flowchart TD
#     A[Start] --> B{Is it?};
#     B -->|Yes| C[OK];
#     C --> D[Rethink];
#     D --> B;
#     B ---->|No| E[End];
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# flowchart TD
#     A[Start] --&gt; B{Is it?};
#     B --&gt;|Yes| C[OK];
#     C --&gt; D[Rethink];
#     D --&gt; B;
#     B ----&gt;|No| E[End];
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 250
#
# graph TD;
#     A-->B;
#     A-->C;
#     B-->D;
#     C-->D;
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# graph TD;
#     A--&gt;B;
#     A--&gt;C;
#     B--&gt;D;
#     C--&gt;D;
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="250"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 350
#
# sequenceDiagram
#     Alice->>John: Hello John, how are you?
#     John-->>Alice: Great!
#     Alice-)John: See you later!
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# sequenceDiagram
#     Alice-&gt;&gt;John: Hello John, how are you?
#     John--&gt;&gt;Alice: Great!
#     Alice-)John: See you later!
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="350"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 350
#
# classDiagram
#     Animal <|-- Duck
#     Animal <|-- Fish
#     Animal <|-- Zebra
#     Animal : +int age
#     Animal : +String gender
#     Animal: +isMammal()
#     Animal: +mate()
#     class Duck{
#       +String beakColor
#       +swim()
#       +quack()
#     }
#     class Fish{
#       -int sizeInFeet
#       -canEat()
#     }
#     class Zebra{
#       +bool is_wild
#       +run()
#     }
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# classDiagram
#     Animal &lt;|-- Duck
#     Animal &lt;|-- Fish
#     Animal &lt;|-- Zebra
#     Animal : +int age
#     Animal : +String gender
#     Animal: +isMammal()
#     Animal: +mate()
#     class Duck{
#       +String beakColor
#       +swim()
#       +quack()
#     }
#     class Fish{
#       -int sizeInFeet
#       -canEat()
#     }
#     class Zebra{
#       +bool is_wild
#       +run()
#     }
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="350"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 350
#
# stateDiagram-v2
#     [*] --> Still
#     Still --> [*]
#     Still --> Moving
#     Moving --> Still
#     Moving --> Crash
#     Crash --> [*]
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# stateDiagram-v2
#     [*] --&gt; Still
#     Still --&gt; [*]
#     Still --&gt; Moving
#     Moving --&gt; Still
#     Moving --&gt; Crash
#     Crash --&gt; [*]
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="350"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 250 -o gantt.html
#
# gantt
#     title Computational Thinking Studies
#     dateFormat  YYYY-MM-DD
#     section Python
#     Python Basic         :a1, 2022-03-01, 7d
#     Python Intermediate  :after a1, 7d
#     section Packages
#     Numpy                :2022-03-15, 5d
#     Matplotlib           :4d
#     Pandas               :2022-03-18, 7d
# Out:
#         <iframe
#             width="100%"
#             height="250"
#             src="gantt.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %%mermaid_magic -h 500
#
# pie title Pets adopted by volunteers
#     "Dogs" : 386
#     "Cats" : 85
#     "Rats" : 15
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# pie title Pets adopted by volunteers
#     &quot;Dogs&quot; : 386
#     &quot;Cats&quot; : 85
#     &quot;Rats&quot; : 15
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 650
#
# erDiagram
#           CUSTOMER }|..|{ DELIVERY-ADDRESS : has
#           CUSTOMER ||--o{ ORDER : places
#           CUSTOMER ||--o{ INVOICE : "liable for"
#           DELIVERY-ADDRESS ||--o{ ORDER : receives
#           INVOICE ||--|{ ORDER : covers
#           ORDER ||--|{ ORDER-ITEM : includes
#           PRODUCT-CATEGORY ||--|{ PRODUCT : contains
#           PRODUCT ||--o{ ORDER-ITEM : "ordered in"
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# erDiagram
#           CUSTOMER }|..|{ DELIVERY-ADDRESS : has
#           CUSTOMER ||--o{ ORDER : places
#           CUSTOMER ||--o{ INVOICE : &quot;liable for&quot;
#           DELIVERY-ADDRESS ||--o{ ORDER : receives
#           INVOICE ||--|{ ORDER : covers
#           ORDER ||--|{ ORDER-ITEM : includes
#           PRODUCT-CATEGORY ||--|{ PRODUCT : contains
#           PRODUCT ||--o{ ORDER-ITEM : &quot;ordered in&quot;
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="650"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 400
#
# journey
#     title My working day
#     section Go to work
#       Make tea: 5: Me
#       Go upstairs: 3: Me
#       Do work: 1: Me, Cat
#     section Go home
#       Go downstairs: 5: Me
#       Sit down: 3: Me
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# journey
#     title My working day
#     section Go to work
#       Make tea: 5: Me
#       Go upstairs: 3: Me
#       Do work: 1: Me, Cat
#     section Go home
#       Go downstairs: 5: Me
#       Sit down: 3: Me
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="400"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 150
#
#     gitGraph
#        commit
#        commit
#        branch develop
#        commit
#        commit
#        commit
#        checkout main
#        commit
#        commit
#        merge develop
#        commit
#        commit
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
#     gitGraph
#        commit
#        commit
#        branch develop
#        commit
#        commit
#        commit
#        checkout main
#        commit
#        commit
#        merge develop
#        commit
#        commit
#
#         &lt;/div&gt;
#
#     &lt;/body&gt;
# &lt;/html&gt;
# " width="100%" height="150"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# %%mermaid_magic -h 350
#
# %%{init: { 'logLevel': 'debug', 'theme': 'base', 'gitGraph': {'showBranches': false,'showCommitLabel': false}} }%%
#       gitGraph
#         commit
#         branch hotfix
#         checkout hotfix
#         commit
#         branch develop
#         checkout develop
#         commit id:"ash"
#         branch featureB
#         checkout featureB
#         commit type:HIGHLIGHT
#         checkout main
#         checkout hotfix
#         commit type:NORMAL
#         checkout develop
#         commit type:REVERSE
#         checkout featureB
#         commit
#         checkout main
#         merge hotfix
#         checkout featureB
#         commit
#         checkout develop
#         branch featureA
#         commit
#         checkout develop
#         merge hotfix
#         checkout featureA
#         commit
#         checkout featureB
#         commit
#         checkout develop
#         merge featureA
#         branch release
#         checkout release
#         commit
#         checkout main
#         commit
#         checkout release
#         merge main
#         checkout develop
#         merge release
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# %%{init: { &#x27;logLevel&#x27;: &#x27;debug&#x27;, &#x27;theme&#x27;: &#x27;base&#x27;, &#x27;gitGraph&#x27;: {&#x27;showBranches&#x27;: false,&#x27;showCommitLabel&#x27;: false}} }%%
#       gitGraph
#         commit
#         branch hotfix
#         checkout hotfix
#         commit
#         branch develop
#         checkout develop
#         commit id:&quot;ash&quot;
#         branch featureB
#         checkout featureB
#         commit type:HIGHLIGHT
#         checkout main
#         checkout hotfix
#         commit type:NORMAL
#         checkout develop
#         commit type:REVERSE
#         checkout featureB
#         commit
#         checkout main
# ...

# %% [markdown]
# ## [waversurfer](https://wavesurfer-js.org/)

# %%
# %wavesurfer_magic -f https://ia802606.us.archive.org/35/items/shortpoetry_047_librivox/abou_ben_adhem_hunt_mlb.mp3
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://unpkg.com/wavesurfer.js/dist/wavesurfer.js&quot;&gt;&lt;/script&gt;
#         &lt;div id=&quot;wavesurfer&quot;&gt;
#             &lt;div id=&quot;waveform&quot;&gt;&lt;/div&gt;
#             &lt;div class=&quot;controls&quot;&gt;
#                 &lt;button class=&quot;btn btn-primary&quot; data-action=&quot;play&quot;&gt;
#                     &lt;i class=&quot;glyphicon glyphicon-play&quot;&gt;&lt;/i&gt;
#                     Play
#                     /
#                     &lt;i class=&quot;glyphicon glyphicon-pause&quot;&gt;&lt;/i&gt;
#                     Pause
#                 &lt;/button&gt;
#             &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;script&gt;
#             var GLOBAL_ACTIONS = { // eslint-disable-line
#                 play: function() {
#                     window.wavesurfer.playPause();
#                 },
#
#                 back: function() {
# ...

# %%
# import os

# os.remove('flowchart.html')
# os.remove('gantt.html')
